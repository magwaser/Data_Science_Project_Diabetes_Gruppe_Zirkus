# %% [markdown]
# # Data Science Diabetes Project <a id='back'></a>

# %% [markdown]
# <blockquote>
#     <a href = "#1.0" style = 'color:DarkGoldenRod; text-decoration: none; font-size: 15px'>
#         1. Load packages
#     </a>
# </blockquote>
# <blockquote>
#     <a href = "#2.0" style = 'color:DarkGoldenRod; text-decoration: none; font-size: 15px'>
#         2. Data Description
#     </a>
#     <blockquote>
#         <a href = "#2.1" style = 'color:DarkGoldenRod; text-decoration: none; font-size: 15px'>
#             2.1 Data Column Meaning
#         </a>
#     </blockquote>
#     <blockquote>
#         <a href = "#2.2" style = 'color:DarkGoldenRod; text-decoration: none; font-size: 15px'>
#             2.2 Data Distribution
#         </a>
#     </blockquote>
#     <blockquote>
#         <a href = "#2.3" style = 'color:DarkGoldenRod; text-decoration: none; font-size: 15px'>
#             2.3 Data Imputation
#         </a>
#     </blockquote>
# </blockquote>
# <blockquote>
#     <a href = "#3.0" style = 'color:DarkGoldenRod; text-decoration: none; font-size: 15px'>
#         3. Data visualization
#     </a>
# </blockquote>
# <blockquote>
#     <a href = "#4.0" style = 'color:DarkGoldenRod; text-decoration: none; font-size: 15px'>
#         4. Check for Correlation
#     </a>
#     <blockquote>
#         <a href = "#4.1" style = 'color:DarkGoldenRod; text-decoration: none; font-size: 15px'>
#             4.1 The multicollinearity variance inflation factor (VIF)
#         </a>
#     </blockquote>
# </blockquote>
# <blockquote>
#     <a href = "#5.0" style = 'color:DarkGoldenRod; text-decoration: none; font-size: 15px'>
#         5. Data Preprocessing
#     </a>
# </blockquote>
# <blockquote>
#     <a href = '#6.0' style = 'color:DarkGoldenRod; text-decoration: none; font-size: 15px'>
#         6. Hyperparameters
#     </a>
#     <blockquote>
#         <a href = "#6.1" style = 'color:DarkGoldenRod; text-decoration: none; font-size: 15px'>
#             6.1 Square Root Method for best K in KNN
#         </a>
#     </blockquote>
#     <blockquote>
#         <a href = "#6.2" style = 'color:DarkGoldenRod; text-decoration: none; font-size: 15px'>
#             6.2 Hyperparameter tuning function for RF
#         </a>
#     </blockquote>
# </blockquote>
# <blockquote>
#     <a href = '#7.0' style = 'color:DarkGoldenRod; text-decoration: none; font-size: 15px'>
#         7. Training of Maschine Learning Tools
#     </a>
#     <blockquote>
#         <a href = "#7.1" style = 'color:DarkGoldenRod; text-decoration: none; font-size: 15px'>
#             7.1 Maschine Learning Tools
#         </a>
#     </blockquote>
#     <blockquote>
#         <a href = "#7.2" style = 'color:DarkGoldenRod; text-decoration: none; font-size: 15px'>
#             7.2 Random Forest
#         </a>
#     </blockquote>
# </blockquote>
# <blockquote>
#     <a href = "#8.0" style = 'color:DarkGoldenRod; text-decoration: none; font-size: 15px'>
#         8. Normalized Feature importance
#     </a>
# </blockquote>
# <blockquote >
#     <a href = '#9.0' style = 'color:DarkGoldenRod; text-decoration: none; font-size: 15px'>
#         9. Classifier Evaluation
#     </a>
#     <blockquote>
#         <a href = "#9.1" style = 'color:DarkGoldenRod; text-decoration: none; font-size: 15px'>
#             9.1 Evaluation Performance Function
#         </a>
#     </blockquote>
#     <blockquote>
#         <a href = "#9.2" style = 'color:DarkGoldenRod; text-decoration: none; font-size: 15px'>
#             9.2 K-fold performance function
#         </a>
#     </blockquote>
#     <blockquote>
#         <a href = "#9.3" style = 'color:DarkGoldenRod; text-decoration: none; font-size: 15px'>
#             9.3 Evaluation of binary classifiers
#         </a>
#     </blockquote>
#     <blockquote>
#         <a href = "#9.4" style = 'color:DarkGoldenRod; text-decoration: none; font-size: 15px'>
#             9.4 first Evaluation Results
#         </a>
#     </blockquote>
#     <blockquote>
#         <a href = "#9.5" style = 'color:DarkGoldenRod; text-decoration: none; font-size: 15px'>
#             9.5 Random Oversampling
#         </a>
#     </blockquote>
#     <blockquote>
#         <a href = "#9.6" style = 'color:DarkGoldenRod; text-decoration: none; font-size: 15px'>
#             9.6 Receiver Operator Characteristics
#         </a>
#     </blockquote>
# </blockquote>

# %% [markdown]
# ## 1. Load Packages <a id =1.0></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

# %%
from sklearn import svm

from sklearn.model_selection import train_test_split, KFold, GridSearchCV, StratifiedKFold, train_test_split, RandomizedSearchCV

from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report

from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LinearRegression, Ridge, Lasso, LogisticRegression

from sklearn.feature_selection import SelectFromModel, SelectKBest, f_classif

from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_iris
from sklearn.utils.validation import column_or_1d

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# %%
#Für Class imbalance
import imblearn
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

# %% [markdown]
# [need help installing packages?](#id)

# %% [markdown]
# ## 2. Data Description <a id =2.0></a>

# %%
data = pd.read_csv('../data/diabetes.csv') #relativer Pfad
print(data.shape)
# Out:
# (768, 9)

# %%
print((data.duplicated()== True).sum())
# Out:
# 0

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# None

# %%
display(data.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
print(data.isna().sum())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
print((data == 0).sum())
# Out:
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     we seem to have a lot of missing values
# </div>

# %% [markdown]
# ### 2.1 Diabetes Column Description <a id =2.1></a>
#
# **Pregnancies:** # of pregnancies
# **Glucose:** Plasma glucose concentration over 2 hours in an oral glucose tolerance test
# **BloodPressure:** Diastolic blood pressure (mm Hg)
# **SkinThickness:** Triceps skin fold thickness (mm)
# **Insulin:** 2-Hour serum insulin ($\frac {U}{ml}$)
# **BMI:** Body mass index ($\frac{kg}{m^2}$)
# **DiabetesPedigreeFunction:** Diabetes pedigree function (a function which scores likelihood of diabetes based on family history)
# **Age:** Age (years)
# **Outcome:** Class variable (0 if non-diabetic, 1 if diabetic)

# %% [markdown]
# ### 2.2 Data Distribution  <a id ='2.2'></a>

# %%
#histoplots um die Datenverteilung anzusehen.
fig2, ax2 = plt.subplots(2,4, figsize=(18,12))
units = ['#','mg/dl','mm Hg', 'mm','U/ml','kg/m^2', 'score', 'years']
for i, feature in enumerate(data.columns.drop('Outcome')):
    plot = sns.histplot(data[feature], ax = ax2.flat[i], kde = True)
    ax2.flat[i].set(title = '{}\n distribution'.format(feature))
    ax2.flat[i].set(xlabel = '{} [{}]'.format(feature, units[i]))
plt.tight_layout(pad = 2)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     Wee seem to have a lot of 0 Values. In some cases they are not very plausible:
#     <ul>
#         <li style = 'color:red'>
#             <b>Glucose</b> = 0. Is that possible????. Maybe they were fasting prior testing?
#         </li>
#         <li>
#             <b>BloodPressure</b> = 0 mm Hg, would mean death. We also have some Values around 20, which seems very low.
#         </li>
#         <li style = 'color:red'>
#             <b>SkinThickness</b> = 0 mm, is verrrrry thin and the data curve looks unnatural :(
#         </li>
#         <li>
#             <b>BMI</b> = 0, would mean death. The rest seems possible.
#         </li>
#         <li>
#             <b>Insulin</b> = 0, could be?. Some sources say yes
#         </li>
#     </ul>
# </div><hr>

# %% [markdown]
# ### 2.3 Data Imputation <a id = '2.3'></a>
#
# Im folgenden Block ersetzten wir die Null-Werte von den Spalten:' BloodPressure, SkinThickness, BMI' mit Werten, die sie, basierend auf ihren Nachbarn, am ehesten einnehmen würden. Diese Imputation führen wir mit einem KNN-imputer durch.

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=27, missing_values=0) #27 = sqrt(#rows)
feature = ['BloodPressure', 'SkinThickness', 'BMI','Glucose']
data_alt = data # alte daten sichern, bevor sie überschrieben werden.
for feat in feature:
    data_imp = imputer.fit_transform(data[[feat]])
    data[feat] = data_imp.ravel()

display(data.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0       35.00000        0  33.6
# 1            1     85.0           66.0       29.00000        0  26.6
# 2            8    183.0           64.0       29.15342        0  23.3
# 3            1     89.0           66.0       23.00000       94  28.1
# 4            0    137.0           40.0       35.00000      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
print((data == 0).sum())
# Out:
# Pregnancies                 111
# Glucose                       0
# BloodPressure                 0
# SkinThickness                 0
# Insulin                     374
# BMI                           0
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %% [markdown]
# <a href = '#back' style = '
#   background-color: blue;
#   color: white;
#   padding: 1em 1em;
#   text-decoration: none;
#   text-transform: uppercase;
#   font-size: 30px'>
#     &uarr;
# </a>

# %% [markdown]
# ## 3. Data visualization <a id ="3.0"></a>
#
# First we want to check how many People in our dataset are diabetic vs non-diabetic

# %%
print(data['Outcome'].mean()) #check that Outcome.dtype is still int64 or float64
# Out:
# 0.3489583333333333

# %%
fig, ax = plt.subplots(figsize = (7,5))
outcome_count = data["Outcome"].value_counts()
outcome_count = pd.DataFrame(outcome_count)
outfig = sns.barplot(data = outcome_count, y = 'Outcome', x = outcome_count.index, ax = ax)
ax.set(ylabel = "Count", title = 'Outcome counts')
ax.set_xticklabels(["non-diabetic", 'diabetic'])
ax.bar_label(ax.containers[0], fmt='%.0f')
fig.tight_layout()

# %%
fig, ax = plt.subplots(3,3, figsize=(18,12))
fig.delaxes(ax.flatten()[-1])
units = ['#','mg/dl','mm Hg', 'mm', 'U/ml', 'kg/m^2', 'score', 'years']
for i, feature in enumerate(data.columns.drop('Outcome')):
    non_diab = np.mean(data[feature][data['Outcome'] == 0])
    diab = np.mean(data[feature][data['Outcome'] == 1])
    ok = [non_diab, diab]
    frame = pd.DataFrame(ok)
    plot = sns.barplot(x = frame.index, y = frame[0], ax = ax.flat[i])
    ax.flat[i].set(ylabel = units[i], title = 'Mean value\n{}'.format(feature))
    ax.flat[i].set_xticklabels(["non-diabetic", 'diabetic'])
    ax.flat[i].bar_label(ax.flat[i].containers[0], fmt='%.0f', padding = -15)
plt.tight_layout(pad = 2)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Our dataset is not balanced: # non-diabetic > # diabetic
# </div>

# %% [markdown]
# ## 4. Check for Correlation <a id = "4.0"></a>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     Outcome.dtype sollte noch float64 sein. <br>
#     Funktioniert nicht mit "category"!
# </div>

# %%
# test for correlation
corr = data.corr()
display(corr)
sns.heatmap(corr, 
         xticklabels=corr.columns, 
         yticklabels=corr.columns).set(title='Pearson Correlation')
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.127911       0.208522       0.082989
# Glucose                      0.127911  1.000000       0.218367       0.192991
# BloodPressure                0.208522  0.218367       1.000000       0.192816
# SkinThickness                0.082989  0.192991       0.192816       1.000000
# Insulin                     -0.073535  0.331080      -0.046829       0.112974
# BMI                          0.021565  0.230941       0.281268       0.542398
# DiabetesPedigreeFunction    -0.033523  0.137060      -0.002763       0.100966
# Age                          0.544341  0.266534       0.324595       0.127872
# Outcome                      0.221898  0.492928       0.166074       0.215299
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.021565                 -0.033523
# ...

# %% [markdown]
# ### Mögliche störende Collinearität unter den Features:
# <span style="color:red">
#     Pearson's Correlation
# </span>
#
# * Pregnancies & Age (**0.54**)
# * SkinThickness & BMI (**0.54**)
#
# ***

# %% [markdown]
# <a href = '#back' style = '
#   background-color: blue;
#   color: white;
#   padding: 1em 1.5em;
#   text-decoration: none;
#   text-transform: uppercase;'>
#     Go to the top
# </a>

# %% [markdown]
# ### 4.1 The multicollinearity variance inflation factor (VIF) <a id='4.1'></a>
# ... can be calculated to figure out the
# standard of tolerance and assess the degree of collinearity

# %%
# compute the vif for all given features
def compute_vif(considered_features):
    
    X = data[considered_features]
    # the calculation of variance inflation requires a constant
    X['intercept'] = 1
    
    # create dataframe to store vif values
    vif = pd.DataFrame()
    vif["Variable"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif = vif[vif['Variable']!='intercept']
    return vif

# von: https://towardsdatascience.com/targeting-multicollinearity-with-python-3bd3b4088d0b

# %%
# features to consider removing
considered_features = ['Pregnancies','Glucose','BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']


# compute vif 
compute_vif(considered_features).sort_values('VIF', ascending=False)
# Out:
#                    Variable       VIF
# 7                       Age  1.622234
# 5                       BMI  1.581915
# 3             SkinThickness  1.447484
# 0               Pregnancies  1.432871
# 1                   Glucose  1.299772
# 2             BloodPressure  1.253600
# 4                   Insulin  1.204490
# 6  DiabetesPedigreeFunction  1.062043

# %% [markdown]
# <div class="alert alert-block alert-success">
#     Kein VIF Score ist über 5
#     -> Vermutlich keine multi-collinearity vorhanden
# </div>

# %% [markdown]
# <a href = '#back' style = '
#   background-color: blue;
#   color: white;
#   padding: 1em 1.5em;
#   text-decoration: none;
#   text-transform: uppercase;'>
#     Go to the top
# </a>

# %% [markdown]
# ## 5. Data Preprocessing <a id ='5.0'></a>

# %%
num_columns = ['Pregnancies','Glucose','BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']
cat_columns = ['Outcome']
data[cat_columns] = data[cat_columns].astype('category') # War vorher noch float64

# %%
X = data[num_columns]# features
y = data[cat_columns] # Outcome ist die einzige cat, label

# %%
# y_1d = column_or_1d(y) # convert y.shape to 1d array, We do that later in the code

# %%
X_model, X_rest, y_model, y_rest = train_test_split(
    X, y, test_size=0.2,random_state = 69, stratify=y
) # Random state = 69, so that we get the same resulst when running this code again.

# %%
sc = StandardScaler() # nicht alle Variabeln haben die gleiche Einheit/ Dimension
X_model[num_columns] = sc.fit_transform(X_model[num_columns])
X_rest[num_columns]  = sc.transform(X_rest[num_columns])

# %% [markdown]
# <div class="alert alert-block alert-info">
#     We split the data into a model-dataset and a rest. <br>
#     With the model data we fit our classifiers and do first evaluations. <br>
#     The rest dataset is for the final evaluation, as they are not used beforehand.
# </div>

# %% [markdown]
# ## 6. Hyperparameters <a id = '6.0'></a>

# %% [markdown]
# ### 6.1 Square Root Method for best K in KNN <a id = '6.1'></a>

# %%
np.sqrt(X_model.shape[0]) # Wurzel aus Anzahl rows
# Out:
# 24.779023386727733

# %% [markdown]
# <div class="alert alert-block alert-info">
#     We take K = 25, because K should be an odd number
# </div><hr>

# %% [markdown]
# ### 6.2 Hyperparameter tuning function for RF <a id = '6.2'></a>

# %%
def RF_hyper(X_test, y_test):
    param_grid = {
    'n_estimators': [25, 50, 100, 150],
    'max_features': ['sqrt', 'log2', None],
    'max_depth': [3, 6, 9],
    'max_leaf_nodes': [3, 6, 9],
    }
    random_search = RandomizedSearchCV(RandomForestClassifier(),param_grid, random_state = 69)
    random_search.fit(X_test, y_test)
    
    best_para = random_search.best_params_
    max_depth, max_features, max_leaf_nodes, n_estimators = best_para['max_depth'],best_para['max_features'],best_para['max_leaf_nodes'],best_para['n_estimators']
    
    return max_depth, max_features, max_leaf_nodes, n_estimators

# %%
y_1d_model = column_or_1d(y_model)
max_depth, max_features, max_leaf_nodes, n_estimators = RF_hyper(X_model, y_1d_model)

# %% [markdown]
# ## 7. Training of Maschine Learning Tools <a id = '7.0'></a>

# %% [markdown]
# ### 7.1 Maschine Learning Tools <a id = '7.1'></a>

# %%
y_model_1d = column_or_1d(y_model)

clf_SVM = svm.SVC(probability=True, kernel = 'linear') # Support Vector Maschine
clf_SVM.fit(X_model, y_model_1d)

clf_LR = LogisticRegression(random_state=1) # Logistische Regression
clf_LR.fit(X_model, y_model_1d)

clf_RF = RandomForestClassifier(random_state=1, max_depth = max_depth, max_features = max_features, max_leaf_nodes = max_leaf_nodes, n_estimators = n_estimators) # Random Forest
clf_RF.fit(X_model, y_model_1d)

clf_KNN = KNeighborsClassifier(n_neighbors= 25) # K-Nearest Neighbors
clf_KNN.fit(X_model, y_model_1d)
# Out:
# KNeighborsClassifier(n_neighbors=25)

# %% [markdown]
# <h2>7.2 Random Forest</h2> <a id = "7.2"></a>
# <div class="alert alert-block alert-info">
#     This is just for visualizing and understanding a RF<br>
#     (Abgebildet ist nur ein Teil von einem zufällig ausgewählten Baum)
# </div>

# %%
from sklearn import tree
fig = plt.figure(figsize=(50,50))
_ = tree.plot_tree(clf_RF.estimators_[2],
                   feature_names=X.columns,
                   class_names=X.index.astype(str),
                   filled=True,
                  max_depth=2)
#plt.savefig("../plots/RF.png")

# %% [markdown]
# <a href = '#back' style = '
#   background-color: blue;
#   color: white;
#   padding: 1em 1.5em;
#   text-decoration: none;
#   text-transform: uppercase;'>
#     Go to the top
# </a>

# %% [markdown]
# ## 8. Normalized feature importance <a id = '8.0'></a>

# %%
coefficients = clf_LR.coef_
importance = np.abs(coefficients)
# Normalize the absolute coefficients to obtain feature importance scores
importance_scores = (importance / np.sum(importance)).flatten()

fig, ax = plt.subplots(figsize=(18, 6))
ax.bar(np.arange(len(importance_scores)), importance_scores)
ax.set_xticks(
    np.arange(len(importance_scores)), X.columns.tolist(), rotation=90
)  # set the xticks according to the feature names, and rotate them by 90 degrees
ax.set_title("Normalized feature importance Log. Regression", fontsize=20)
ax.set_ylabel('importance scores')
#plt.savefig('../features.png')
plt.show()

# %%
coefficients = clf_SVM.coef_
importance = np.abs(coefficients)
# Normalize the absolute coefficients to obtain feature importance scores
importance_scores = (importance / np.sum(importance)).flatten()

fig, ax = plt.subplots(figsize=(18, 6))
ax.bar(np.arange(len(importance_scores)), importance_scores)
ax.set_xticks(
    np.arange(len(importance_scores)), X.columns.tolist(), rotation=90
)  # set the xticks according to the feature names, and rotate them by 90 degrees
ax.set_title("Normalized feature importance SVM", fontsize=20)
ax.set_ylabel('importance scores')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     We chose not to delete any feature, since we only have 8 and they don't seem to have any multicollinearity
# </div>

# %%
importance_scores = clf_RF.feature_importances_

fig, ax = plt.subplots(figsize=(18, 6))
ax.bar(np.arange(len(importance_scores)), importance_scores)
ax.set_xticks(
    np.arange(len(importance_scores)), X.columns.tolist(), rotation=90
)  # set the xticks according to the feature names, and rotate them by 90 degrees
ax.set_title("feature importance Random Forest", fontsize=20)
ax.set_ylabel('importance scores')
plt.show()

# %% [markdown]
# <a href = '#back' style = '
#   background-color: blue;
#   color: white;
#   padding: 1em 1.5em;
#   text-decoration: none;
#   text-transform: uppercase;'>
#     Go to the top
# </a>

# %% [markdown]
# ## 9. Performance evaluation <a id ='9.0'></a>

# %% [markdown]
# ### 9.1 eval_Performance Funktionen <a id ='9.1'></a>

# %%
# Funktion für die Maschine Learning Evaluation
def eval_Performance(y_eval, X_eval, clf):
    '''
    y_eval = y_test
    X_eval = X_test
    clf = Maschine Learning Tool. (E.G. Log. Regression)
    '''
    
    # predict y based on our Maschine learning Model and create confusion matrix
    y_pred = clf.predict(X_eval) 
    y_pred_proba = clf.predict_proba(X_eval)[:, 1] 
    tn, fp, fn, tp = confusion_matrix(y_eval, y_pred).ravel() # true negatives & positives, false neg. & pos. 

    # Evaluation
    accuracy  = accuracy_score(y_eval, y_pred)
    precision = precision_score(y_eval, y_pred)
    specificity = tn / (tn + fp)
    recall    = recall_score(y_eval, y_pred)
    f1        = f1_score(y_eval, y_pred)
    fp_rates, tp_rates, _ = roc_curve(y_eval, y_pred_proba) # false-positive and true-positive rate

    # Calculate the area under the roc curve
    roc_auc = auc(fp_rates, tp_rates)

    return tp,fp,tn,fn,accuracy, specificity, precision, recall, f1, roc_auc

# %%
# implementiere den Performance DataFrame
df_performance = pd.DataFrame(columns = ['tp','fp','tn','fn','accuracy', 'specificity','precision', 'recall', 'f1', 'roc_auc'] )
# still empty

# %% [markdown]
# ---
# ### 9.2 K-Fold performance function <a id ='9.2'></a>

# %% [markdown]
# Die flolgende Funktion berechnet die Performance für alle 4 CLFs bei einem gegebenem Datensatz

# %%
def K_fold_performance(X, y, K):
    '''
    X = feature
    y = labels
    K = hyperparameter for KNN
    '''
    # implementiere den Performance DatdaFrame
    df_performance = pd.DataFrame(columns = ['tp','fp','tn','fn','accuracy', 'specificity','precision', 'recall', 'f1', 'roc_auc'] )
    
    # implementiere Hilfsdatasätze, für die Cross Validation
    df_performance_SVM_test = pd.DataFrame(columns = ['tp','fp','tn','fn','accuracy', 'specificity','precision', 'recall', 'f1', 'roc_auc'] )
    df_performance_SVM_train = pd.DataFrame(columns = ['tp','fp','tn','fn','accuracy', 'specificity','precision', 'recall', 'f1', 'roc_auc'] )

    df_performance_LR_test = pd.DataFrame(columns = ['tp','fp','tn','fn','accuracy', 'specificity','precision', 'recall', 'f1', 'roc_auc'] )
    df_performance_LR_train = pd.DataFrame(columns = ['tp','fp','tn','fn','accuracy', 'specificity','precision', 'recall', 'f1', 'roc_auc'] )

    df_performance_RF_test = pd.DataFrame(columns = ['tp','fp','tn','fn','accuracy', 'specificity','precision', 'recall', 'f1', 'roc_auc'] )
    df_performance_RF_train = pd.DataFrame(columns = ['tp','fp','tn','fn','accuracy', 'specificity','precision', 'recall', 'f1', 'roc_auc'] )

    df_performance_KNN_test = pd.DataFrame(columns = ['tp','fp','tn','fn','accuracy', 'specificity','precision', 'recall', 'f1', 'roc_auc'] )
    df_performance_KNN_train = pd.DataFrame(columns = ['tp','fp','tn','fn','accuracy', 'specificity','precision', 'recall', 'f1', 'roc_auc'] )
    
    # Implement a 5-fold stratified crossvalidation loop with relevant data standardization.

    # Perform a 5-fold crossvalidation - prepare the splits
    n_splits = 5
    skf      = StratifiedKFold(n_splits=n_splits)

    # counter to save our performance metrics for each crossvalidation fold
    fold = 0
    
    # Maschine learning tools
    
    clf_SVM = svm.SVC(probability=True, kernel = 'linear', random_state = 1) # Support Vector Maschine

    clf_LR = LogisticRegression(random_state=1)

    clf_KNN = KNeighborsClassifier(n_neighbors= K) # K-Nearest Neighbors
    # random_state, so we have the same results. Better for this groupproject, otherwise we would have a little chaos in our group.
    
    # prepare a list to save our clf models for later.
    classi = []

    # Loop over all splits
    for train_index, test_index in skf.split(X, y):

        # Get the relevant subsets for training and testing
        X_test  = X.iloc[test_index]
        y_test  = y.iloc[test_index]
        X_train = X.iloc[train_index]
        y_train = y.iloc[train_index]

        #transform y to an 1d array (better for sklearn)
        y_test = column_or_1d(y_test, warn=False)
        y_train = column_or_1d(y_train, warn=False)


        # Standardize the numerical features using training set statistics
        sc = StandardScaler()
        X_train_sc = sc.fit_transform(X_train)
        X_test_sc  = sc.transform(X_test)

        # Randomforest, but with hyperparameter tuning
        max_depth, max_features, max_leaf_nodes, n_estimators = RF_hyper(X_model, y_model_1d) # we defined this function in chapter ...
        clf_RF = RandomForestClassifier(random_state=1, max_depth = max_depth, max_features = max_features, max_leaf_nodes = max_leaf_nodes, n_estimators = n_estimators)
        
        # Creat prediction models and fit them to the training data

        # Logistic regression
        clf_LR.fit(X_train_sc, y_train)

        # Random forest
        clf_RF.fit(X_train_sc, y_train)

        #Support Vector Maschine
        clf_SVM.fit(X_train_sc, y_train)

        # K Nearest Neighbors
        clf_KNN.fit(X_train_sc, y_train)
        
        # save each clf for each fold. 
        classi.append(clf_SVM)
        classi.append(clf_LR)
        classi.append(clf_KNN)
        classi.append(clf_RF)

        # save the evaluation metrics in our aid-dataframes. (For each Fold)
        df_performance_SVM_test.loc[fold, : ] = eval_Performance(y_test, X_test_sc, clf_SVM)
        df_performance_SVM_train.loc[fold, : ] = eval_Performance(y_train, X_train_sc, clf_SVM)

        df_performance_LR_test.loc[fold, : ] = eval_Performance(y_test, X_test_sc, clf_LR)
        df_performance_LR_train.loc[fold, : ] = eval_Performance(y_train, X_train_sc, clf_LR)

        df_performance_RF_test.loc[fold, : ] = eval_Performance(y_test, X_test_sc, clf_RF)
        df_performance_RF_train.loc[fold, : ] = eval_Performance(y_train, X_train_sc, clf_RF)

        df_performance_KNN_test.loc[fold, : ] = eval_Performance(y_test, X_test_sc, clf_KNN)
        df_performance_KNN_train.loc[fold, : ] = eval_Performance(y_train, X_train_sc, clf_KNN)

        # increase counter for folds
        fold += 1
    
    # get the mean evaluation metrics over all folds and save them in another dataframe
    df_performance.loc['SVM (test)',:] = column_or_1d(df_performance_SVM_test.mean().round(3))
    df_performance.loc['SVM (train)',:] = column_or_1d(df_performance_SVM_train.mean().round(3))

    df_performance.loc['LR (test)',:] = column_or_1d(df_performance_LR_test.mean().round(3))
    df_performance.loc['LR (train)',:] = column_or_1d(df_performance_LR_train.mean().round(3))

    df_performance.loc['KNN (test)',:] = column_or_1d(df_performance_KNN_test.mean().round(3))
    df_performance.loc['KNN (train)',:] = column_or_1d(df_performance_KNN_train.mean().round(3))

    df_performance.loc['RF (test)',:] = column_or_1d(df_performance_RF_test.mean().round(3))
    df_performance.loc['RF (train)',:] = column_or_1d(df_performance_RF_train.mean().round(3))
    
    #return all calculated tables and classifiers
    return df_performance, classi, df_performance_SVM_test, df_performance_LR_test, df_performance_KNN_test, df_performance_RF_test

# %% [markdown]
# <a href = '#back' style = '
#   background-color: blue;
#   color: white;
#   padding: 1em 1.5em;
#   text-decoration: none;
#   text-transform: uppercase;'>
#     Go to the top
# </a>
# <a href = '#res' style = '
#   background-color: SlateBlue;
#   color: white;
#   padding: 1em 1.5em;
#   text-decoration: none;
#   text-transform: uppercase;'>
#     Final evaluations
# </a>

# %% [markdown]
# ## 9.3 Evaluation of binary classifiers <a id = '9.3'></a>
#
# Classification tasks are very common in data science applications and a large variety of evaluation metrics exist. For a data scientist it is important to understand how to calculate these evaluation metrics, but also to know when to use which of these. The basis for most evaluation metrics is the confusion matrix:
#
# ![sensitivity_vs_specificity.jpeg](attachment:sensitivity_vs_specificity.jpeg)
#
# #### 1. Accuracy
#
# Accuracy is the most straightforward metric for classification. It measures the proportion of correct predictions out of the total number of predictions made.
#
# \begin{align*}
#    \text{Accuray} &= \frac{TP+TN}{TP + TN + FP + FN}
# \end{align*}
# #### 2. Precision
#
# Precision, also known as positive predictive value, measures the proportion of true positive predictions out of all positive predictions made. It evaluates the model's ability to correctly identify positive instances.
#
# \begin{align*}
#    \text{Precision} &= \frac{TP}{TP + FP}
# \end{align*}
#
# #### 3. Recall
#
# Recall, also known as sensitivity or true positive rate, measures the proportion of true positive predictions out of all actual positive instances. It evaluates the model's ability to identify all positive instances.
#
# \begin{align*}
#    \text{Recall} &= \frac{TP}{TP + FN}
# \end{align*}
#
# #### 4. F1 Score
#
# F1 Score is the harmonic mean of precision and recall. It provides a balanced measure between precision and recall, especially when dealing with imbalanced datasets.
#
# \begin{align*}
#    \text{F1 Score} &= \frac{TP}{TP + 0.5\cdot(FN + FP)}
# \end{align*}

# %% [markdown]
# #### 5. Receiver Operator Characteristic (ROC)
#
# The ROC curve shows the performance of a classifier at **all classification thresholds** by plotting the True Positive Rate (TPR) as a function of the False Positive Rate (FPR). The area under this curve (AUC) is a measure of classification performance.
#
# ##
#
#
# \begin{align*}
#    \text{TPR} &= \frac{TP}{TP + FN}
# \end{align*}
#
#
# ##
#
# \begin{align*}
#    \text{FPR} &= \frac{FP}{FP + TN}
# \end{align*}

# %% [markdown]
# <div class="alert alert-block alert-info">
#     chapter 9.3 is from the Tutorials. This is just for us, so we can check again the metric definitions.
# </div>

# %% [markdown]
# ### 9.4 first Performance Results <a id ='9.4'> </a>

# %%
np.sqrt(X_model.shape[0]*0.8) # hyperparameter for KNN. In next step we have a smaller Training set size -> K = 23
# Out:
# 22.16303228351211

# %%
tab_1, clfs,sv,lr,knn,rf  = K_fold_performance(X_model, y_model, K = 23) # this might take a minute
tab_1
# Out:
#                 tp    fp     tn    fn accuracy specificity precision recall  \
# SVM (test)    23.8  11.0   69.0  19.0    0.756       0.862     0.681  0.556
# SVM (train)   95.0  39.2  280.8  76.2    0.765       0.878     0.709  0.555
# LR (test)     23.6  11.2   68.8  19.2    0.752        0.86     0.677  0.551
# LR (train)    93.2  40.0  280.0  78.0     0.76       0.875       0.7  0.544
# KNN (test)    21.6  11.6   68.4  21.2    0.733       0.855     0.651  0.505
# KNN (train)   94.8  34.8  285.2  76.4    0.774       0.891     0.732  0.554
# RF (test)     24.8  12.2   67.8  18.0    0.754       0.847      0.67   0.58
# RF (train)   113.6  36.6  283.4  57.6    0.808       0.886     0.757  0.664
#
#                 f1 roc_auc
# SVM (test)   0.611    0.82
# SVM (train)  0.622   0.834
# LR (test)    0.607   0.825
# LR (train)   0.612   0.835
# KNN (test)   0.567   0.811
# KNN (train)   0.63   0.845
# RF (test)     0.62   0.816
# RF (train)   0.707   0.893

# %% [markdown]
# <a href = '#9.3' style = '
#   background-color: purple;
#   color: white;
#   padding: 1em 1.5em;
#   text-decoration: none;
#   text-transform: uppercase;'>
#     Go to metric definitions
# </a>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     those results are the mean values over a 5 fold stratified cross validation:<br>
#     The '(train)' indicates that the model was validated with the same data as it was trained.<br>
#     These are just here to check if the models are over- or underfitted and were'nt used for the clf evaluations. <br>
#     For the clf evaluation we just take the (test) rows.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Our classifiers are in general accurat and precise. <br>
#     Yet no model is good at identifying all positive instances. This could be, because our dataset is imbalanced and we have way more non-diabetic cases than diabetic.
# </div>

# %%
display(sv, lr, knn, rf) # alle folds für die performance von SVM, LR, KNN & RF
# Out:
#    tp  fp  tn  fn  accuracy specificity precision    recall        f1  \
# 0  19  12  68  24  0.707317        0.85  0.612903   0.44186  0.513514
# 1  22  11  69  21  0.739837      0.8625  0.666667  0.511628  0.578947
# 2  23  12  68  20  0.739837        0.85  0.657143  0.534884  0.589744
# 3  29   8  72  14  0.821138         0.9  0.783784  0.674419     0.725
# 4  26  12  68  16  0.770492        0.85  0.684211  0.619048      0.65
#
#     roc_auc
# 0  0.806395
# 1  0.789826
# 2   0.78343
# 3  0.877326
# 4  0.841964
#    tp  fp  tn  fn  accuracy specificity precision    recall        f1  \
# 0  20  12  68  23  0.715447        0.85     0.625  0.465116  0.533333
# 1  23  11  69  20  0.747967      0.8625  0.676471  0.534884  0.597403
# 2  23  14  66  20  0.723577       0.825  0.621622  0.534884     0.575
# 3  28   9  71  15  0.804878      0.8875  0.756757  0.651163       0.7
# 4  24  10  70  18  0.770492       0.875  0.705882  0.571429  0.631579
#
#     roc_auc
# 0  0.807558
# 1  0.798256
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
#     For the evaluation with the rest of our datapoints we chose: <br>
#     for SVM: Fold 4 (highest in every category)<br>
#     for LR: Fold 4 (highest in every category)<br>
#     for KNN: Fold 5 (best roc_auc) <br>
#     for RF: Fold 4 (best in all)<br>
#     since they are the best models for now.
# </div>

# %%
clfs[12], clfs[13], clfs[18], clfs[15] # just to be sure we get the right classifiers
# those indixes refer to the blue box above
# Out:
# (SVC(kernel='linear', probability=True, random_state=1),
#  LogisticRegression(random_state=1),
#  KNeighborsClassifier(n_neighbors=23),
#  RandomForestClassifier(max_depth=9, max_features=None, max_leaf_nodes=9,
#                         n_estimators=25, random_state=1))

# %%
# save Model bevor rewriting our clfs array
SVM_best = clfs[12]
LR_best = clfs[13]
KNN_best = clfs[18]
RF_best = clfs[15]

# %%
# Now we evaluate our best models with the rest-dataset, that hasn't been used at all.(completely new data)
df_performance.loc['SVM',:]= eval_Performance(y_rest, X_rest, SVM_best)
df_performance.loc['LR',:]= eval_Performance(y_rest, X_rest, LR_best)
df_performance.loc['KNN',:]= eval_Performance(y_rest, X_rest, KNN_best)
df_performance.loc['RF',:]= eval_Performance(y_rest, X_rest, RF_best)
display(df_performance)
# Out:
# /Users/magnuswaser/miniconda3/lib/python3.10/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(
# /Users/magnuswaser/miniconda3/lib/python3.10/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(
# /Users/magnuswaser/miniconda3/lib/python3.10/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/magnuswaser/miniconda3/lib/python3.10/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/magnuswaser/miniconda3/lib/python3.10/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
#     These are now the best selected models from before, <br>and they are evaluated with the rest dataset, that has been put aside at the beginning.<br> The rest data hasn't been used for any maschine learning training at all.
# </div>

# %%
#display(tab_1) #just the mean values from before

# %% [markdown]
# <div class="alert alert-block alert-info">
#     All the best selected models perform slightly worse than before (as expected). <br>
#     All models have a good specificity.(correctly identifying negatives)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     for now LR seems to be the best Model based on our evaluation metrics
# </div>

# %% [markdown]
# <a href = '#back' style = '
#   background-color: blue;
#   color: white;
#   padding: 1em 1.5em;
#   text-decoration: none;
#   text-transform: uppercase;'>
#     Go to the top
# </a>

# %% [markdown]
# ### 9.5 Random Oversampling <a id = '9.5'></a>

# %%
# definiere die Oversampling Strategie: Die 'Minority' wird aufgestockt.
# somit haben wir nun 400 diabetic und 400 non-diabetic Fälle im Modeldataset.
oversample = RandomOverSampler(sampling_strategy='all')
# fit and apply the transform
X_over, y_over = oversample.fit_resample(X_model, y_model)
X_over.shape[0], y_over.shape[0]
# Out:
# (800, 800)

# %%
y_over.value_counts()
# Out:
# Outcome
# 0          400
# 1          400
# dtype: int64

# %%
np.sqrt(X_over.shape[0]*0.8) # K = 25, training dataset got bigger
# Out:
# 25.298221281347036

# %%
tab_ov, clfs, sv, lr, knn, rf = K_fold_performance(X_over, y_over, K = 25) #this might take a minute
display(tab_1,tab_ov)
# upper table: results from before
# lower table: results for oversampling
# Out:
#                 tp    fp     tn    fn accuracy specificity precision recall  \
# SVM (test)    23.8  11.0   69.0  19.0    0.756       0.862     0.681  0.556
# SVM (train)   95.0  39.2  280.8  76.2    0.765       0.878     0.709  0.555
# LR (test)     23.6  11.2   68.8  19.2    0.752        0.86     0.677  0.551
# LR (train)    93.2  40.0  280.0  78.0     0.76       0.875       0.7  0.544
# KNN (test)    21.6  11.6   68.4  21.2    0.733       0.855     0.651  0.505
# KNN (train)   94.8  34.8  285.2  76.4    0.774       0.891     0.732  0.554
# RF (test)     24.8  12.2   67.8  18.0    0.754       0.847      0.67   0.58
# RF (train)   113.6  36.6  283.4  57.6    0.808       0.886     0.757  0.664
#
#                 f1 roc_auc
# SVM (test)   0.611    0.82
# SVM (train)  0.622   0.834
# LR (test)    0.607   0.825
# LR (train)   0.612   0.835
# KNN (test)   0.567   0.811
# KNN (train)   0.63   0.845
# RF (test)     0.62   0.816
# RF (train)   0.707   0.893
# ...

# %% [markdown]
# <a href = '#9.3' style = '
#   background-color: purple;
#   color: white;
#   padding: 1em 1.5em;
#   text-decoration: none;
#   text-transform: uppercase;'>
#     Go to metric definitions
# </a>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Durch das Oversamplen der Diabetic-Fälle , verbessern sich die CLF in fast allen Aspekten. <br>
#     Sie verlieren zwar alle etwas an Spezifität, sind dafür aber um einiges sensitiver geworden.
# </div>

# %%
display(sv, lr, knn, rf) # alle folds für die performance von SVM, LR, KNN & RF (Oversampled)
# Out:
#    tp  fp  tn  fn accuracy specificity precision  recall        f1   roc_auc
# 0  52  17  63  28  0.71875      0.7875  0.753623    0.65  0.697987  0.815625
# 1  58  22  58  22    0.725       0.725     0.725   0.725     0.725  0.824375
# 2  60  19  61  20  0.75625      0.7625  0.759494    0.75  0.754717  0.833984
# 3  50  18  62  30      0.7       0.775  0.735294   0.625  0.675676  0.831875
# 4  57  21  59  23    0.725      0.7375  0.730769  0.7125  0.721519  0.810547
#    tp  fp  tn  fn accuracy specificity precision  recall        f1   roc_auc
# 0  53  18  62  27  0.71875       0.775  0.746479  0.6625  0.701987  0.814688
# 1  61  23  57  19   0.7375      0.7125   0.72619  0.7625  0.743902  0.825313
# 2  59  19  61  21     0.75      0.7625   0.75641  0.7375  0.746835  0.832969
# 3  52  19  61  28  0.70625      0.7625  0.732394    0.65  0.688742  0.835156
# 4  58  20  60  22   0.7375        0.75   0.74359   0.725  0.734177   0.82375
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
#     For the evaluation with the rest data we chose: <br>
#     for SVM: Fold 3 <br>
#     for LR: Fold 3 <br>
#     for KNN: Fold 4<br>
#     for RF: Fold 4 <br>
#     since they are the best models
# </div>

# %%
clfs[8], clfs[9], clfs[14], clfs[15] # just to be sure we get the right classifiers
# Out:
# (SVC(kernel='linear', probability=True, random_state=1),
#  LogisticRegression(random_state=1),
#  KNeighborsClassifier(n_neighbors=25),
#  RandomForestClassifier(max_depth=3, max_leaf_nodes=9, random_state=1))

# %%
# save the best clf
SVM_best_over = clfs[8]
LR_best_over = clfs[9]
KNN_best_over = clfs[14]
RF_best_over = clfs[15]

# %%
# save the evaluation metrics for the best clf models (evaluated with the rest-dataset).
# & display the oversampled with the normal metrics
df_performance.loc['SVM (over)',:]= eval_Performance(y_rest, X_rest, SVM_best_over)
df_performance.loc['LR (over)',:]= eval_Performance(y_rest, X_rest, LR_best_over)
df_performance.loc['KNN (over)',:]= eval_Performance(y_rest, X_rest, KNN_best_over)
df_performance.loc['RF (over)',:]= eval_Performance(y_rest, X_rest, RF_best_over)
display(df_performance)
# Out:
# /Users/magnuswaser/miniconda3/lib/python3.10/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(
# /Users/magnuswaser/miniconda3/lib/python3.10/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(
# /Users/magnuswaser/miniconda3/lib/python3.10/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/magnuswaser/miniconda3/lib/python3.10/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/magnuswaser/miniconda3/lib/python3.10/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# ...

# %%
'''
import dataframe_image as dfi
df_style = df_performance.style.background_gradient(cmap = 'PuBu')
dfi.export(df_performance, "perf.png",  table_conversion="matplotlib")

screenshot would have been 100 times better
'''
# Out:
# '\nimport dataframe_image as dfi\ndf_style = df_performance.style.background_gradient(cmap = \'PuBu\')\ndfi.export(df_performance, "perf.png",  table_conversion="matplotlib")\n\nscreenshot would have been 100 times better\n'

# %% [markdown]
# <a href = '#9.3' style = '
#   background-color: purple;
#   color: white;
#   padding: 1em 1em;
#   text-decoration: none;
#   text-transform: uppercase;'>
#     Go to metric definitions
# </a>
# <a id ='res' ></a>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Im Vergleich zu den 1. Modelldurchläufen verbessern sich die overfitted clfs nur ganz wenig im Bereich der roc_auc. <br>
#     Eine klare verbesserung sieht man aber bei den recall-werten.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Evaluated with the rest-data, the performance of KNN decreases again, but is still a good classifier.<br><br>
#     All roc_auc and recall values get better with the oversampled data. But we lose in accuracy, specificity and precision.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     So based on our evaluation we would choose the <b>logistic regression model</b>, because it has the highest roc_auc values and is very specific and accurat. <br>
#     But SVM performs very good aswell.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     The Oversampled Models aren't that much better in the f1-score than before, altough they increase the sensitivity. In contrary they perform much worse for the accuracy, specificity and precision score.
#     <br><br>
#     So we would stick to not-oversampled models, but depending on what we want to measure the oversampled models might be better
#
# </div>

# %% [markdown]
# <a href = '#back' style = '
#   background-color: blue;
#   color: white;
#   padding: 1em 1.5em;
#   text-decoration: none;
#   text-transform: uppercase;'>
#     Go to the top
# </a>

# %% [markdown]
# ### 9.6 Receiver Operator Characteristic ROC <a id ='9.6' ></a>

# %% [markdown]
# Die folgende Funktion wird für das Zeichnen des Random classifiers im ROC-plot benötigt

# %%
def add_identity(axes, *line_args, **line_kwargs):
    identity, = axes.plot([], [], *line_args, **line_kwargs)
    def callback(axes):
        low_x, high_x = axes.get_xlim()
        low_y, high_y = axes.get_ylim()
        low = max(low_x, low_y)
        high = min(high_x, high_y)
        identity.set_data([low, high], [low, high])
    callback(axes)
    axes.callbacks.connect('xlim_changed', callback)
    axes.callbacks.connect('ylim_changed', callback)
    return axes

# %%
# Implement a 5-fold stratified crossvalidation loop with relevant data standardization.

# Perform a 5-fold crossvalidation - prepare the splits
n_splits = 5
skf      = StratifiedKFold(n_splits=n_splits)

# Use this counter to save your performance metrics for each crossvalidation fold
# also plot the roc curve for each model and fold into a joint subplot
fold = 0
fig,axs = plt.subplots(2,2,figsize=(12, 9))

# Loop over all splits
for train_index, test_index in skf.split(X_over, y_over):

    # Get the relevant subsets for training and testing
    X_test  = X_over.iloc[test_index]
    y_test  = y_over.iloc[test_index]
    X_train = X_over.iloc[train_index]
    y_train = y_over.iloc[train_index]
    
    #transform y to an 1d array (better for sklearn)
    y_test = column_or_1d(y_test, warn=False)
    y_train = column_or_1d(y_train, warn=False)


    # Standardize the numerical features using training set statistics
    sc = StandardScaler()
    X_train_sc = sc.fit_transform(X_train)
    X_test_sc  = sc.transform(X_test)


    # Creat prediction models and fit them to the training data

    # Logistic regression
    clf_LR = LogisticRegression(random_state=1)
    clf_LR.fit(X_train_sc, y_train)

    # Random forest
    max_depth, max_features, max_leaf_nodes, n_estimators = RF_hyper(X_model, y_model_1d)
    clf_RF = RandomForestClassifier(random_state=1, max_depth = max_depth, max_features = max_features, max_leaf_nodes = max_leaf_nodes, n_estimators = n_estimators)
        
    clf_RF.fit(X_train_sc, y_train)
    
    #Support Vector Maschine
    clf_SVM = svm.SVC(probability=True, kernel = 'linear') # Support Vector Maschine
    clf_SVM.fit(X_train_sc, y_train)

    # K Nearest Neighbors
    clf_KNN = KNeighborsClassifier(n_neighbors= 25) # K-Nearest Neighbors
    clf_KNN.fit(X_train_sc, y_train)

    # Get the roc curve using a sklearn function
    y_test_predict_proba_LR  = clf_LR.predict_proba(X_test_sc)[:, 1]
    fp_rates_LR, tp_rates_LR, _ = roc_curve(y_test, y_test_predict_proba_LR)
    
    y_test_predict_proba_RF  = clf_RF.predict_proba(X_test_sc)[:, 1]
    fp_rates_RF, tp_rates_RF, _ = roc_curve(y_test, y_test_predict_proba_RF)
   
    y_test_predict_proba_SVM  = clf_SVM.predict_proba(X_test_sc)[:, 1]
    fp_rates_SVM, tp_rates_SVM, _ = roc_curve(y_test, y_test_predict_proba_SVM)
   
    y_test_predict_proba_KNN  = clf_KNN.predict_proba(X_test_sc)[:, 1]
    fp_rates_KNN, tp_rates_KNN, _ = roc_curve(y_test, y_test_predict_proba_KNN)
    
    # Plot on the provided axis
    axs.flat[0].plot(fp_rates_LR, tp_rates_LR,label='fold ' + str(fold))
    axs.flat[1].plot(fp_rates_RF, tp_rates_RF,label='fold ' + str(fold))
    axs.flat[2].plot(fp_rates_SVM, tp_rates_SVM,label='fold ' + str(fold))
    axs.flat[3].plot(fp_rates_KNN, tp_rates_KNN,label='fold ' + str(fold))
    
    # increase counter for folds
    fold += 1

# Make plot pretty
model_names = ['LR','RF', 'SVM', 'KNN']
for i,ax in enumerate(axs.flat):
    ax.set_xlabel('FPR')
    ax.set_ylabel('TPR')
    add_identity(ax, color="b", ls="--",label = 'random\nclassifier')
    ax.legend()
    ax.title.set_text('ROC ' +model_names[i])
plt.tight_layout()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     These are the ROC curves for the still overfitted models.<br>(Just for visualization of ROC and to compare to the evaluated ROC-Scores down below)
# </div>

# %%
fig,axs = plt.subplots(2,2,figsize=(12, 9))

# Get the roc curve using a sklearn function
y_test_predict_proba_LR  = LR_best.predict_proba(X_rest)[:, 1]
fp_rates_LR, tp_rates_LR, _ = roc_curve(y_rest, y_test_predict_proba_LR)
    
y_test_predict_proba_RF  = RF_best.predict_proba(X_rest)[:, 1]
fp_rates_RF, tp_rates_RF, _ = roc_curve(y_rest, y_test_predict_proba_RF)
   
y_test_predict_proba_SVM  = SVM_best.predict_proba(X_rest)[:, 1]
fp_rates_SVM, tp_rates_SVM, _ = roc_curve(y_rest, y_test_predict_proba_SVM)
   
y_test_predict_proba_KNN  = KNN_best.predict_proba(X_rest)[:, 1]
fp_rates_KNN, tp_rates_KNN, _ = roc_curve(y_rest, y_test_predict_proba_KNN)
    
# Plot on the provided axis
axs.flat[0].plot(fp_rates_LR, tp_rates_LR,label='best LR-perfomance on rest data', color = 'orange')
axs.flat[1].plot(fp_rates_RF, tp_rates_RF,label='best RF-perfomance on rest data',color = 'orange')
axs.flat[2].plot(fp_rates_SVM, tp_rates_SVM,label='best SVM-perfomance on rest data',color = 'orange')
axs.flat[3].plot(fp_rates_KNN, tp_rates_KNN,label='best KNN-perfomance on rest data',color = 'orange')
    
# Make plot pretty
model_names = ['LR_over','RF_over', 'SVM_over', 'KNN_over']
for i,ax in enumerate(axs.flat):
    ax.set_xlabel('FPR')
    ax.set_ylabel('TPR')
    add_identity(ax, color="b", ls="--",label = 'random\nclassifier')
    ax.legend()
    ax.title.set_text('ROC ' +model_names[i])
plt.tight_layout()
# Out:
# /Users/magnuswaser/miniconda3/lib/python3.10/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /Users/magnuswaser/miniconda3/lib/python3.10/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /Users/magnuswaser/miniconda3/lib/python3.10/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(
# /Users/magnuswaser/miniconda3/lib/python3.10/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(

# %% [markdown]
# <div class="alert alert-block alert-info">
#    These are the ROC-Curves for the best Modelperformance, evaluated with the rest-dataset. As we can see they are worse than the curves above
# </div>

# %% [markdown]
# <a id="id"></a>
# So packages in jupyter installiere:
# > import <span style="color:blue">sys</span>
# !{<span style="color:blue">sys</span>.executable} -m pip install ###
#
# ---
#
# > sklearn = scikit-learn

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <b>ENDE GUT ALLES GUT</b>
# </div>

# %% [markdown]
# <a href = '#back' style = '
#   background-color: blue;
#   color: white;
#   padding: 1em 1.5em;
#   text-decoration: none;
#   text-transform: uppercase;'>
#     Go to the top
# </a>

# %%
pip list
# Out:
# Package                           Version
# --------------------------------- --------
# aiohttp                           3.8.4
# aiosignal                         1.3.1
# appnope                           0.1.2
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# asttokens                         2.0.5
# async-timeout                     4.0.2
# attrs                             21.4.0
# backcall                          0.2.0
# beautifulsoup4                    4.11.1
# bleach                            4.1.0
# brotlipy                          0.7.0
# certifi                           2023.5.7
# cffi                              1.15.1
# charset-normalizer                2.0.4
# conda                             23.1.0
# conda-content-trust               0.1.3
# conda-package-handling            2.0.2
# conda_package_streaming           0.7.0
# contourpy                         1.0.7
# cryptography                      38.0.4
# ...
